# %% [markdown]
# # Classificação das espécies de Íris
#
# Aluno: Anderson Silva Fonseca
#
# ## Objetivo
#
# O objetivo deste trabalho é criar um modelo de Machine Learning de classificação (ou regressão), utilizando boas práticas de programação.
# Em vez de usar os classificadores convencionais, este projeto usou uma rede neural convolucional, visando os seguintes objetivos específicos:
#
#     * Criar um modelo que possa ser facilmente modificado sem ter que alterar outros modelos
#     * Criar rotinas que sejam executadas por todos os modelos e criar rotinas específicas que só são conhecidas pelo seu próprio modelo
#
# ## User History
#
# Como analista de espécies de plantas e árvores, quero obter um relatório completo sobre as espécies de flores encontradas na área urbana da cidade para criar um planejamento arbóreo que evite o aumento de casos de alergia nos centros da cidade e maximizem os benefícios da área verde como redução das pegadas de carbono e da temperatura.
#
# ## Detalhamento Simplificado
#
# ### Problema
#
# Dentro do patrimônio público da cidade, temos catalogadas cada muda de flores que foi plantada em praças públicas, porém com o passar do tempo percebeu-se o aumento da quantidade de flores e cruzamento destas plantas. Com a finalidade de catalogar as novas plantas, precisamos de um modelo que seja capaz de reconhecer o tipo da planta com uma acurácia maior que 70%. Visando diminuir o tempo de análise dos especialistas sugerindo uma possível espécie de planta.
#
# ### Benefícios
#
# Reduzir o tempo de campo dos especialistas em condições desfavoráveis (sol e transporte)
# Estudar as consequências do aumento de plantas do gênero na cidade
#
# ### Trade-off
#
# É melhor remover possíveis plantas que estão classificadas incorretamente do que deixar uma planta que possa degradar a saúde da população.
#
# ### Dados
#
# Os dados podem ser obtidos a partir das imagens privadas retiradas das praças públicas durante o sensoriamento arbóreo. Os dados não precisam ser atualizados com uma frequência muito alto, mas recomenda-se atualizá-la a cada 6 meses.
#
# ### Obtenção dos resultados
#
# O resultado da classificação do modelo pode ser obtido durante a categorização das plantas do centro urbano.
#
# ### Entrada e saída dos dados
#
# A entrada dos dados são imagens das flores tiradas durante o dia. A saída será um valor único indicado qual a espécie determinada flor pertence.
#
# ### Algoritmos
#
# Gostaríamos de testar os algoritmos de classificação de imagem mais conhecidas atualmente com diferentes hiperparâmetros
#
# ### Baseline
#
# Como modelo base, foi sugerido usar modelos de classificação que são usados com o dataset Iris
#
# ### Gold Dataset
#
# Um bom dataset para nosso modelo é que os dados estejam corretamente catalogados com suas determinadas espécies

# %%
# Imports
from matplotlib import pyplot as plt
import numpy as np

from src.datasets.iris_dataset import IrisDataset
from src.preprocessing.image_pre_processor import ImagePreProcessor
from src.models.unet import UNet
from src.evaluation.evaluator import Evaluator
from src.runner.runner import Runner

# %% [markdown]
# ## Coleta e Análise dos dados
#
# ### Obtenção dos dados
#
# Os dados foram obtidos a partir de um dataset disponibilizado no [kaggle](https://www.kaggle.com/datasets/jeffheaton/iris-computer-vision?resource=download).
#
# > Por se tratar de um dataset de imagens não é possível usar a API para descompactar as imagens, então seus dados foram baixados e colocados dentro da pasta `data/iris/`
#
# ### Código-Fonte
#
# #### Classe DatasetLoader
#
# A classe `DatasetLoader` é uma classe abstrata que engloba as principais funções que toda classe que carrega dataset deve ter. No contexto atual, ela responsável pode recuperar o dado bruto, o conjunto de labels e os respectivos conjuntos de dados para `x` e `y`, ou features e label respectivamente.
#
# #### Classe DatasetLoader
#
# A classe `IrisDataset` é uma classe que herda de `DatasetLoader`. Foi feita uma sobrecarga nos métodos para que ela seja capaz de acessar o dataset da Iris e que ela conheça todas as labels relacionadas.
#
# ### Exploração dos dados

# %%
iris_dataset = IrisDataset("data/iris")
example_images = iris_dataset.get_x()[:10]

fig = plt.figure(figsize =(12,5))
columns = 5
rows = 2

for i in range(len(example_images)):
    ax = fig.add_subplot(rows, columns, i)
    plt.imshow(example_images[i])

plt.show()

# %%
print(f"Labels: {iris_dataset.get_label_names()}")

# %%
print("Distribuição dos dados")

labels, counts = np.unique(iris_dataset.get_y(), return_counts = True)

plt.figure(figsize=(10, 5))
fig, ax = plt.subplots()
bars = ax.barh(iris_dataset.get_label_names(), counts)

ax.bar_label(bars)

# %% [markdown]
# ## Pré-processamento
#
# ### Código-Fonte
#
# #### Classe PreProcessor
#
# A classe `PreProcessor` é uma classe abstrata que engloba as principais para realizar o pré-processamento No contexto atual, ela responsável por aplicar as transformações básicas em `x` e `y`. Atualmente ela também é responsável por fazer a divisão de treino/teste/validação.
#
# #### Classe ImagePreProcessor
#
# A classe `ImagePreProcessor` é uma classe que herda de `PreProcessor` e tem como principal característica fazer o tratamento de dados baseados em imagem. Sua principal caracteristica é que ela é capaz de ler as imagens, fazer uma normalização baseada nos canais e realizar uma reamostragem em cada imagem do dataset.
#
# ### Resultados do pré-processamento

# %%
preprocessor = ImagePreProcessor(iris_dataset)

# %%
print(f"Original Shape: {example_images[0].shape}")
print(f"Processed Shape: {preprocessor.get_x()[0].shape}")
print(f"Original Min: {np.min(iris_dataset.get_x())} - Original Max: {np.max(iris_dataset.get_x())}")
print(f"Original Min: {np.min(preprocessor.get_x())} - Original Max: {np.max(preprocessor.get_x())}")

# %% [markdown]
# ## Modelos de Classificação
#
# Os modelos de classificação utilizados nesse trabalho são baseados usando o framework `tensorflow`.
#
# ### Código Fonte
#
# #### Classe BaseModel
#
# A classe `BaseModel` é uma classe abstrata que visa encapsular os componentes essenciais de um modelo de rede neural baseado no tensorflow. Além disso, esta classe foi adaptada para ter as seguintes funcionalidades adicionais.
#
# * Identificação única de treinamentos
#
#     Toda classe que herda de `BaseModel` recebe um identificador único durante o treinamento, facilitando dos logs gerados pela aplicação
#
# * Painel Tensorboard
#
#     Durante o treinamento de um modelo baseado no `BaseModel`, por padrão é criado uma callback que armazena os logs do treinamento dentro do tensorboard. As métricas são armazenadas em uma pasta dentro dos logs com identificado único do treinamento.
#
#     > Caso o usuário já tenha criado sua instância do tensorboard, esta funcionalidade é desativada para evitar demoras na execução
#
# * Model Checkpoint
#
#     Por padrão, qualquer treinamento realizado no BaseModel possui os seus pesos salvos automaticamente usando um ModelCheckpoint. Seus pesos são salvos dentro do log.
#
# * Sugestão de hiperparâmetros
#
#     O modelo pode inferir os hiperparâmetros que podem ser alterados
#
# > Todas essas funcionalidades criadas podem ser desativadas com argumentos fornecidos na documentação
#
# #### Classe UNet
#
# A classe UNet herda as funcionalidades de `BaseModel`. Ela apresenta dentro de sim todas as camadas para a criação da UNet baseada no artigo.

# %%
model = UNet()

# %% [markdown]
# ## Métodos de Avaliação
#
# Para avaliar o modelo foram usadas as métricas acurácia, precisão, recall, f1 score e a matriz de confusão.
#
# ### Código Fonte
#
# #### Classe Evaluator
#
# A classe `Evaluator` possui um conjunto de métodos que calculam as métricas a partir do resultados preditos e os dados verdadeiros. Ela possui também funções para salvar a matriz de confusão e as métricas em um arquivo.

# %%
evaluator = Evaluator()

# %% [markdown]
# ## Execução do modelo
#
# Para executar o modelo foi criada uma classe `Runner` que recebe o dataset original, o preprocessador, o modelo-alvo, e um conjunto de métricas de avaliação
#
# ### Código Fonte
#
# #### Classe Runner
#
# A classe `Runner` possui todo um conjunto de métodos para executar o pipeline do tensorflow para a geração do modelo. Durante sua inicialização, os dados são preparados para execução. Sua função `run()` engloba as seguintes etapas
#
# 1. Recuperar hiperparâmetros do modelo-alvo. (Ex.: nº de filtros, batch_normalization, etc)
# 2. Recuperar hiperparâmetros de compilação do modelo (Ex.: Otimizadores, nº de épocas,  etc)
# 3. Geração de hiperparâmetros e suas variações. Cria todas as possibilidades de hiperparâmetros
# 4. Gera o modelo com os hiperparâmetro escolhidos.
# 5. Realiza o treinamento
# 6. Recupera os identificadores únicos de treinamento de cada modelo
# 7. Realiza a predição
# 8. Usa o conjunto de métricas de avaliação fornecido para gerar os resultados
# 9. Salva as métricas e parâmetros dentro da pasta do modelos gerados.
# 10. Retorna um dataframe para análise dos resultados

# %%
runner = Runner(iris_dataset, preprocessor, model, evaluator)

# %%
results = runner.run()
# Out:
# Epoch 1/150
# 19/19 [==============================] - 15s 506ms/step - loss: 0.9277 - accuracy: 0.6258 - val_loss: 1.0250 - val_accuracy: 0.7353
# Epoch 2/150
# 19/19 [==============================] - 6s 342ms/step - loss: 0.8699 - accuracy: 0.6490 - val_loss: 1.0275 - val_accuracy: 0.7647
# Epoch 3/150
# 19/19 [==============================] - 4s 207ms/step - loss: 0.8504 - accuracy: 0.6424 - val_loss: 0.9863 - val_accuracy: 0.7647
# Epoch 4/150
# 19/19 [==============================] - 4s 212ms/step - loss: 0.7966 - accuracy: 0.6556 - val_loss: 0.9340 - val_accuracy: 0.7647
# Epoch 5/150
# 19/19 [==============================] - 4s 221ms/step - loss: 0.7687 - accuracy: 0.6689 - val_loss: 0.8753 - val_accuracy: 0.7353
# Epoch 6/150
# 19/19 [==============================] - 4s 203ms/step - loss: 0.7531 - accuracy: 0.6656 - val_loss: 0.9117 - val_accuracy: 0.7647
# Epoch 7/150
# 19/19 [==============================] - 4s 218ms/step - loss: 0.7393 - accuracy: 0.6689 - val_loss: 0.8568 - val_accuracy: 0.7059
# Epoch 8/150
# 19/19 [==============================] - 4s 214ms/step - loss: 0.6802 - accuracy: 0.7053 - val_loss: 0.8198 - val_accuracy: 0.6765
# Epoch 9/150
# 19/19 [==============================] - 4s 212ms/step - loss: 0.6999 - accuracy: 0.6854 - val_loss: 0.8537 - val_accuracy: 0.6471
# Epoch 10/150
# 19/19 [==============================] - 4s 205ms/step - loss: 0.6400 - accuracy: 0.7020 - val_loss: 0.8902 - val_accuracy: 0.4706
# Epoch 11/150
# 19/19 [==============================] - 4s 222ms/step - loss: 0.7086 - accuracy: 0.6987 - val_loss: 0.8069 - val_accuracy: 0.7647
# Epoch 12/150
# 19/19 [==============================] - 4s 217ms/step - loss: 0
150
# 19/19 [==============================] - 4s 215ms/step - loss: 0.1277 - accuracy: 0.9536 - val_loss: 3.6992 - val_accuracy: 0.5000
# Epoch 36/150
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0862 - accuracy: 0.9735 - val_loss: 3.0710 - val_accuracy: 0.5588
# Epoch 37/150
# 19/19 [==============================] - 4s 214ms/step - loss: 0.1568 - accuracy: 0.9437 - val_loss: 3.2085 - val_accuracy: 0.7059
# Epoch 38/150
# 19/19 [==============================] - 4s 218ms/step - loss: 0.2449 - accuracy: 0.8974 - val_loss: 2.8796 - val_accuracy: 0.6765
# Epoch 39/150
# 19/19 [==============================] - 4s 235ms/step - loss: 0.3256 - accuracy: 0.8709 - val_loss: 7.3799 - val_accuracy: 0.5294
# Epoch 40/150
# 19/19 [==============================] - 4s 215ms/step - loss: 0.2876 - accuracy: 0.8974 - val_loss: 3.4098 - val_accuracy: 0.6765
# Epoch 41/150
# 19/19 [==============================] - 5s 264ms/step - loss: 0.1604 - accuracy: 0.9371 - val_loss: 3.9207 - val_accuracy: 0.6471
# Epoch 42/150
# 19/19 [==============================] - 4s 226ms/step - loss: 0.1963 - accuracy: 0.9205 - val_loss: 4.0345 - val_accuracy: 0.5588
# Epoch 43/150
# 19/19 [==============================] - 4s 209ms/step - loss: 0.1406 - accuracy: 0.9503 - val_loss: 4.1227 - val_accuracy: 0.6176
# Epoch 44/150
# 19/19 [==============================] - 4s 204ms/step - loss: 0.1611 - accuracy: 0.9636 - val_loss: 1.9540 - val_accuracy: 0.6765
# Epoch 45/150
# 19/19 [==============================] - 4s 207ms/step - loss: 0.1564 - accuracy: 0.9570 - val_loss: 2.4153 - val_accuracy: 0.6471
# Epoch 46/150
# 19/19 [==============================] - 4s 226ms/step - loss: 0.0592 - accuracy: 0.9868 - val_loss: 3.8788 - val_accuracy: 0.7059
# Epoch 47/150
# 19/19 [==============================] - 4s 203ms/step - loss: 0.0395 - accuracy: 0.9901 - val_loss: 4.4644 - val_accuracy: 0.5882
# Epoch 48/150
# 19/19 [==============================] - 4s 205ms/step - loss: 0.0634 - accuracy: 0.9834 - val_loss: 3.5962 - val_accuracy: 0.6176
# Epoch 49/150
# 19/19 [==============================] - 4s 208ms/step - loss: 0.0406 - accuracy: 0.9868 - val_loss: 3.2654 - val_accuracy: 0.5882
# Epoch 50/150
# 19/19 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9934Restoring model weights from the end of the best epoch: 20.
# 19/19 [==============================] - 4s 204ms/step - loss: 0.0212 - accuracy: 0.9934 - val_loss: 3.9219 - val_accuracy: 0.5882
# Epoch 50: early stopping
# 3/3 [==============================] - 2s 371ms/step
# Epoch 1/150
# 19/19 [==============================] - 7s 251ms/step - loss: 1.1415 - accuracy: 0.3179 - val_loss: 1.0836 - val_accuracy: 0.4118
# Epoch 2/150
# 19/19 [==============================] - 4s 211ms/step - loss: 0.9059 - accuracy: 0.6457 - val_loss: 1.0592 - val_accuracy: 0.7059
# Epoch 3/150
# 19/19 [==============================] - 4s 216ms/step - loss: 0.8798 - accuracy: 0.6490 - val_loss: 0.9834 - val_accuracy: 0.7353
# Epoch 4/150
# 19/19 [==============================] - 4s 214ms/step - loss: 0.8248 - accuracy: 0.6523 - val_loss: 1.0103 - val_accuracy: 0.7353
# Epoch 5/150
# 19/19 [==============================] - 4s 205ms/step - loss: 0.7149 - accuracy: 0.6589 - val_loss: 0.9954 - val_accuracy: 0.7353
# Epoch 6/150
# 19/19 [==============================] - 4s 217ms/step - loss: 0.4993 - accuracy: 0.6987 - val_loss: 1.0601 - val_accuracy: 0.4706
# Epoch 7/150
# 19/19 [==============================] - 4s 216ms/step - loss: 0.4628 - accuracy: 0.8013 - val_loss: 1.6103 - val_accuracy: 0.1765
# Epoch 8/150
# 19/19 [==============================] - 4s 203ms/step - loss: 0.4719 - accuracy: 0.8113 - val_loss: 1.5291 - val_accuracy: 0.2059
# Epoch 9/150
# 19/19 [==============================] - 4s 218ms/step - loss: 0.4981 - accuracy: 0.8046 - val_loss: 1.6917 - val_accuracy: 0.1176
# Epoch 10/150
# 19/19 [==============================] - 4s 219ms/step - loss: 0.3331 - accuracy: 0.8543 - val_loss: 3.1064 - val_accuracy: 0.2059
# Epoch 11/150
# 19/19 [==============================] - 4s 212ms/step - loss: 0
- val_loss: 0.6987 - val_accuracy: 0.7353
# Epoch 91/150
# 19/19 [==============================] - 15s 786ms/step - loss: 0.7931 - accuracy: 0.6523 - val_loss: 0.6987 - val_accuracy: 0.7353
# Epoch 92/150
# 19/19 [==============================] - ETA: 0s - loss: 0.7926 - accuracy: 0.6523Restoring model weights from the end of the best epoch: 62.
# 19/19 [==============================] - 14s 737ms/step - loss: 0.7926 - accuracy: 0.6523 - val_loss: 0.6988 - val_accuracy: 0.7353
# Epoch 92: early stopping
# 3/3 [==============================] - 1s 375ms/step
# d:\Documents\Workspaces\Python\image-classification\.venv\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Documents\Workspaces\Python\image-classification\.venv\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/150
# 19/19 [==============================] - 10s 433ms/step - loss: 0.9335 - accuracy: 0.6490 - val_loss: 0.9661 - val_accuracy: 0.7353
# Epoch 2/150
# 19/19 [==============================] - 8s 428ms/step - loss: 0.9288 - accuracy: 0.6490 - val_loss: 0.9666 - val_accuracy: 0.7353
# Epoch 3/150
# 19/19 [==============================] - 7s 395ms/step - loss: 0.9247 - accuracy: 0.6490 - val_loss: 0.9628 - val_accuracy: 0.7353
# Epoch 4/150
# 19/19 [==============================] - 7s 397ms/step - loss: 0.9210 - accuracy: 0.6490 - val_loss: 0.9558 - val_accuracy: 0.7353
# Epoch 5/150
# 19/19 [==============================] - 7s 401ms/step - loss: 0.9177 - accuracy: 0.6490 - val_loss: 0.9467 - val_accuracy: 0.7353
# Epoch 6/150
# 19/19 [==============================] - 8s 402ms/step - loss: 0.9149 - accuracy: 0.6490 - val_loss: 0.9360 - val_accuracy: 0.7353
# Epoch 7/150
# 19/19 [==============================] - 7s 402ms/step - loss: 0.9122 - accuracy: 0.6490 - val_loss: 0.9244 - val_accuracy: 0.7353
# Epoch 8/150
# 19/19 [==============================] - 9s 462ms/step - loss: 0.9100 - accuracy: 0.6490 - val_loss: 0.9125 - val_accuracy: 0.7353
# Epoch 9/150
# 19/19 [==============================] - 7s 397ms/step - loss: 0.9079 - accuracy: 0.6490 - val_loss: 0.9005 - val_accuracy: 0.7353
# Epoch 10/150
# 19/19 [==============================] - 8s 410ms/step - loss: 0.9060 - accuracy: 0.6490 - val_loss: 0.8887 - val_accuracy: 0.7353
# Epoch 11/150
# 19/19 [==============================] - 8s 415ms/step - loss: 0.9044 - accuracy: 0.6490 - val_loss: 0.8772 - val_accuracy: 0.7353
# Epoch 12/150
# 19/19 [==============================] - 7s 398ms/step - loss: 0.9029 - accuracy: 0.6490 - val_loss: 0.8662 - val_accuracy: 0.7353
# Epoch 13/150
# 19/19 [==============================] - 8s 416ms/step - loss: 0.9016 - accuracy: 0.6490 - val_loss: 0.8558 - val_accuracy: 0.7353
# Epoch 14/150
# 19/19 [==============================] - 8s 411ms/step - loss: 0.9003 - accuracy: 0.6490 - val_loss: 0.8459 - val_accuracy: 0.7353
# Epoch 15/150
# 19/19 [==============================] - 8s 438ms/step - loss: 0.8993 - accuracy: 0.6490 - val_loss: 0.8368 - val_accuracy: 0.7353
# Epoch 16/150
# 19/19 [==============================] - 8s 427ms/step - loss: 0.8983 - accuracy: 0.6490 - val_loss: 0.8283 - val_accuracy: 0.7353
# Epoch 17/150
# 19/19 [==============================] - 8s 435ms/step - loss: 0.8973 - accuracy: 0.6490 - val_loss: 0.8205 - val_accuracy: 0.7353
# Epoch 18/150
# 19/19 [==============================] - 9s 507ms/step - loss: 0.8965 - accuracy: 0.6490 - val_loss: 0.8134 - val_accuracy: 0.7353
# Epoch 19/150
# 19/19 [==============================] - 8s 444ms/step - loss: 0.8958 - accuracy: 0.6490 - val_loss: 0.8070 - val_accuracy: 0.7353
# Epoch 20/150
# 19/19 [==============================] - 7s 390ms/step - loss: 0.8950 - accuracy: 0.6490 - val_loss: 0.8011 - val_accuracy: 0.7353
# Epoch 21/150
# 19/19 [==============================] - 7s 386ms/step - loss: 0.8944 - accuracy: 0.6490 - val_loss: 0.7958 - val_accuracy: 0.7353
# Epoch 22/150
# 19/19 [==============================] - 7s 383ms/step - loss: 0.8937 - accuracy: 0.6490 - val_loss: 0.7911 - val_accuracy: 0.7353
# Epoch 23/150
# 19/19 [==============================] - 8s 403ms/step - loss: 0.8932 - accuracy: 0.6490 - val_loss: 0.7868 - val_accuracy: 0.7353
# Epoch 24/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8927 - accuracy: 0.6490 - val_loss: 0.7829 - val_accuracy: 0.7353
# Epoch 25/150
# 19/19 [==============================] - 8s 406ms/step - loss: 0.8922 - accuracy: 0.6490 - val_loss: 0.7795 - val_accuracy: 0.7353
# Epoch 26/150
# 19/19 [==============================] - 7s 394ms/step - loss: 0.8917 - accuracy: 0.6490 - val_loss: 0.7764 - val_accuracy: 0.7353
# Epoch 27/150
# 19/19 [==============================] - 7s 398ms/step - loss: 0.8913 - accuracy: 0.6490 - val_loss: 0.7735 - val_accuracy: 0.7353
# Epoch 28/150
# 19/19 [==============================] - 8s 430ms/step - loss: 0.8908 - accuracy: 0.6490 - val_loss: 0.7709 - val_accuracy: 0.7353
# Epoch 29/150
# 19/19 [==============================] - 8s 413ms/step - loss: 0.8904 - accuracy: 0.6490 - val_loss: 0.7685 - val_accuracy: 0.7353
# Epoch 30/150
# 19/19 [==============================] - 8s 413ms/step - loss: 0.8900 - accuracy: 0.6490 - val_loss: 0.7663 - val_accuracy: 0.7353
# Epoch 31/150
# 19/19 [==============================] - 8s 431ms/step - loss: 0.8897 - accuracy: 0.6490 - val_loss: 0.7643 - val_accuracy: 0.7353
# Epoch 32/150
# 19/19 [==============================] - 8s 407ms/step - loss: 0.8893 - accuracy: 0.6490 - val_loss: 0.7625 - val_accuracy: 0.7353
# Epoch 33/150
# 19/19 [==============================] - 7s 398ms/step - loss: 0.8890 - accuracy: 0.6490 - val_loss: 0.7608 - val_accuracy: 0.7353
# Epoch 34/150
# 19/19 [==============================] - 7s 399ms/step - loss: 0.8886 - accuracy: 0.6490 - val_loss: 0.7593 - val_accuracy: 0.7353
# Epoch 35/150
# 19/19 [==============================] - 7s 398ms/step - loss: 0.8883 - accuracy: 0.6490 - val_loss: 0.7579 - val_accuracy: 0.7353
# Epoch 36/150
# 19/19 [==============================] - 7s 402ms/step - loss: 0.8880 - accuracy: 0.6490 - val_loss: 0.7566 - val_accuracy: 0.7353
# Epoch 37/150
# 19/19 [==============================] - 7s 394ms/step - loss: 0.8877 - accuracy: 0.6490 - val_loss: 0.7554 - val_accuracy: 0.7353
# Epoch 38/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8874 - accuracy: 0.6490 - val_loss: 0.7544 - val_accuracy: 0.7353
# Epoch 39/150
# 19/19 [==============================] - 7s 393ms/step - loss: 0.8870 - accuracy: 0.6490 - val_loss: 0.7534 - val_accuracy: 0.7353
# Epoch 40/150
# 19/19 [==============================] - 9s 474ms/step - loss: 0.8868 - accuracy: 0.6490 - val_loss: 0.7526 - val_accuracy: 0.7353
# Epoch 41/150
# 19/19 [==============================] - 7s 384ms/step - loss: 0.8865 - accuracy: 0.6490 - val_loss: 0.7518 - val_accuracy: 0.7353
# Epoch 42/150
# 19/19 [==============================] - 8s 408ms/step - loss: 0.8862 - accuracy: 0.6490 - val_loss: 0.7510 - val_accuracy: 0.7353
# Epoch 43/150
# 19/19 [==============================] - 10s 526ms/step - loss: 0.8860 - accuracy: 0.6490 - val_loss: 0.7504 - val_accuracy: 0.7353
# Epoch 44/150
# 19/19 [==============================] - 10s 519ms/step - loss: 0.8857 - accuracy: 0.6490 - val_loss: 0.7498 - val_accuracy: 0.7353
# Epoch 45/150
# 19/19 [==============================] - 7s 393ms/step - loss: 0.8855 - accuracy: 0.6490 - val_loss: 0.7492 - val_accuracy: 0.7353
# Epoch 46/150
# 19/19 [==============================] - 8s 426ms/step - loss: 0.8852 - accuracy: 0.6490 - val_loss: 0.7487 - val_accuracy: 0.7353
# Epoch 47/150
# 19/19 [==============================] - 7s 384ms/step - loss: 0.8849 - accuracy: 0.6490 - val_loss: 0.7482 - val_accuracy: 0.7353
# Epoch 48/150
# 19/19 [==============================] - 7s 390ms/step - loss: 0.8847 - accuracy: 0.6490 - val_loss: 0.7478 - val_accuracy: 0.7353
# Epoch 49/150
# 19/19 [==============================] - 7s 389ms/step - loss: 0.8845 - accuracy: 0.6490 - val_loss: 0.7473 - val_accuracy: 0.7353
# Epoch 50/150
# 19/19 [==============================] - 7s 398ms/step - loss: 0.8842 - accuracy: 0.6490 - val_loss: 0.7469 - val_accuracy: 0.7353
# Epoch 51/150
# 19/19 [==============================] - 7s 397ms/step - loss: 0.8840 - accuracy: 0.6490 - val_loss: 0.7466 - val_accuracy: 0.7353
# Epoch 52/150
# 19/19 [==============================] - 8s 404ms/step - loss: 0.8838 - accuracy: 0.6490 - val_loss: 0.7462 - val_accuracy: 0.7353
# Epoch 53/150
# 19/19 [==============================] - 7s 399ms/step - loss: 0.8835 - accuracy: 0.6490 - val_loss: 0.7459 - val_accuracy: 0.7353
# Epoch 54/150
# 19/19 [==============================] - 8s 403ms/step - loss: 0.8833 - accuracy: 0.6490 - val_loss: 0.7455 - val_accuracy: 0.7353
# Epoch 55/150
# 19/19 [==============================] - 8s 405ms/step - loss: 0.8831 - accuracy: 0.6490 - val_loss: 0.7452 - val_accuracy: 0.7353
# Epoch 56/150
# 19/19 [==============================] - 7s 385ms/step - loss: 0.8829 - accuracy: 0.6490 - val_loss: 0.7449 - val_accuracy: 0.7353
# Epoch 57/150
# 19/19 [==============================] - 8s 421ms/step - loss: 0.8827 - accuracy: 0.6490 - val_loss: 0.7446 - val_accuracy: 0.7353
# Epoch 58/150
# 19/19 [==============================] - 8s 407ms/step - loss: 0.8825 - accuracy: 0.6490 - val_loss: 0.7444 - val_accuracy: 0.7353
# Epoch 59/150
# 19/19 [==============================] - 8s 402ms/step - loss: 0.8822 - accuracy: 0.6490 - val_loss: 0.7441 - val_accuracy: 0.7353
# Epoch 60/150
# 19/19 [==============================] - 7s 401ms/step - loss: 0.8821 - accuracy: 0.6490 - val_loss: 0.7438 - val_accuracy: 0.7353
# Epoch 61/150
# 19/19 [==============================] - 8s 408ms/step - loss: 0.8819 - accuracy: 0.6490 - val_loss: 0.7436 - val_accuracy: 0.7353
# Epoch 62/150
# 19/19 [==============================] - 7s 394ms/step - loss: 0.8817 - accuracy: 0.6490 - val_loss: 0.7434 - val_accuracy: 0.7353
# Epoch 63/150
# 19/19 [==============================] - 7s 384ms/step - loss: 0.8814 - accuracy: 0.6490 - val_loss: 0.7431 - val_accuracy: 0.7353
# Epoch 64/150
# 19/19 [==============================] - 7s 390ms/step - loss: 0.8812 - accuracy: 0.6490 - val_loss: 0.7429 - val_accuracy: 0.7353
# Epoch 65/150
# 19/19 [==============================] - 7s 386ms/step - loss: 0.8811 - accuracy: 0.6490 - val_loss: 0.7427 - val_accuracy: 0.7353
# Epoch 66/150
# 19/19 [==============================] - 7s 387ms/step - loss: 0.8809 - accuracy: 0.6490 - val_loss: 0.7425 - val_accuracy: 0.7353
# Epoch 67/150
# 19/19 [==============================] - 7s 390ms/step - loss: 0.8807 - accuracy: 0.6490 - val_loss: 0.7422 - val_accuracy: 0.7353
# Epoch 68/150
# 19/19 [==============================] - 7s 396ms/step - loss: 0.8805 - accuracy: 0.6490 - val_loss: 0.7420 - val_accuracy: 0.7353
# Epoch 69/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8803 - accuracy: 0.6490 - val_loss: 0.7418 - val_accuracy: 0.7353
# Epoch 70/150
# 19/19 [==============================] - 7s 401ms/step - loss: 0.8801 - accuracy: 0.6490 - val_loss: 0.7416 - val_accuracy: 0.7353
# Epoch 71/150
# 19/19 [==============================] - 7s 380ms/step - loss: 0.8800 - accuracy: 0.6490 - val_loss: 0.7415 - val_accuracy: 0.7353
# Epoch 72/150
# 19/19 [==============================] - 7s 380ms/step - loss: 0.8797 - accuracy: 0.6490 - val_loss: 0.7413 - val_accuracy: 0.7353
# Epoch 73/150
# 19/19 [==============================] - 7s 387ms/step - loss: 0.8796 - accuracy: 0.6490 - val_loss: 0.7411 - val_accuracy: 0.7353
# Epoch 74/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8794 - accuracy: 0.6490 - val_loss: 0.7409 - val_accuracy: 0.7353
# Epoch 75/150
# 19/19 [==============================] - 7s 381ms/step - loss: 0.8792 - accuracy: 0.6490 - val_loss: 0.7407 - val_accuracy: 0.7353
# Epoch 76/150
# 19/19 [==============================] - 7s 383ms/step - loss: 0.8791 - accuracy: 0.6490 - val_loss: 0.7405 - val_accuracy: 0.7353
# Epoch 77/150
# 19/19 [==============================] - 7s 382ms/step - loss: 0.8789 - accuracy: 0.6490 - val_loss: 0.7404 - val_accuracy: 0.7353
# Epoch 78/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8787 - accuracy: 0.6490 - val_loss: 0.7402 - val_accuracy: 0.7353
# Epoch 79/150
# 19/19 [==============================] - 7s 382ms/step - loss: 0.8785 - accuracy: 0.6490 - val_loss: 0.7400 - val_accuracy: 0.7353
# Epoch 80/150
# 19/19 [==============================] - 7s 401ms/step - loss: 0.8784 - accuracy: 0.6490 - val_loss: 0.7399 - val_accuracy: 0.7353
# Epoch 81/150
# 19/19 [==============================] - 7s 398ms/step - loss: 0.8783 - accuracy: 0.6490 - val_loss: 0.7397 - val_accuracy: 0.7353
# Epoch 82/150
# 19/19 [==============================] - 7s 402ms/step - loss: 0.8780 - accuracy: 0.6490 - val_loss: 0.7396 - val_accuracy: 0.7353
# Epoch 83/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8778 - accuracy: 0.6490 - val_loss: 0.7394 - val_accuracy: 0.7353
# Epoch 84/150
# 19/19 [==============================] - 7s 399ms/step - loss: 0.8777 - accuracy: 0.6490 - val_loss: 0.7393 - val_accuracy: 0.7353
# Epoch 85/150
# 19/19 [==============================] - 7s 399ms/step - loss: 0.8775 - accuracy: 0.6490 - val_loss: 0.7391 - val_accuracy: 0.7353
# Epoch 86/150
# 19/19 [==============================] - 7s 386ms/step - loss: 0.8774 - accuracy: 0.6490 - val_loss: 0.7390 - val_accuracy: 0.7353
# Epoch 87/150
# 19/19 [==============================] - 7s 396ms/step - loss: 0.8772 - accuracy: 0.6490 - val_loss: 0.7388 - val_accuracy: 0.7353
# Epoch 88/150
# 19/19 [==============================] - 7s 383ms/step - loss: 0.8771 - accuracy: 0.6490 - val_loss: 0.7387 - val_accuracy: 0.7353
# Epoch 89/150
# 19/19 [==============================] - 7s 390ms/step - loss: 0.8769 - accuracy: 0.6490 - val_loss: 0.7385 - val_accuracy: 0.7353
# Epoch 90/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8768 - accuracy: 0.6490 - val_loss: 0.7384 - val_accuracy: 0.7353
# Epoch 91/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8766 - accuracy: 0.6490 - val_loss: 0.7382 - val_accuracy: 0.7353
# Epoch 92/150
# 19/19 [==============================] - 8s 434ms/step - loss: 0.8764 - accuracy: 0.6490 - val_loss: 0.7381 - val_accuracy: 0.7353
# Epoch 93/150
# 19/19 [==============================] - 7s 388ms/step - loss: 0.8763 - accuracy: 0.6490 - val_loss: 0.7380 - val_accuracy: 0.7353
# Epoch 94/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8762 - accuracy: 0.6490 - val_loss: 0.7378 - val_accuracy: 0.7353
# Epoch 95/150
# 19/19 [==============================] - 7s 382ms/step - loss: 0.8760 - accuracy: 0.6490 - val_loss: 0.7377 - val_accuracy: 0.7353
# Epoch 96/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8758 - accuracy: 0.6490 - val_loss: 0.7376 - val_accuracy: 0.7353
# Epoch 97/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8757 - accuracy: 0.6490 - val_loss: 0.7374 - val_accuracy: 0.7353
# Epoch 98/150
# 19/19 [==============================] - 7s 380ms/step - loss: 0.8755 - accuracy: 0.6490 - val_loss: 0.7373 - val_accuracy: 0.7353
# Epoch 99/150
# 19/19 [==============================] - 7s 379ms/step - loss: 0.8754 - accuracy: 0.6490 - val_loss: 0.7372 - val_accuracy: 0.7353
# Epoch 100/150
# 19/19 [==============================] - 10s 523ms/step - loss: 0.8752 - accuracy: 0.6490 - val_loss: 0.7370 - val_accuracy: 0.7353
# Epoch 101/150
# 19/19 [==============================] - 7s 380ms/step - loss: 0.8751 - accuracy: 0.6490 - val_loss: 0.7369 - val_accuracy: 0.7353
# Epoch 102/150
# 19/19 [==============================] - 8s 404ms/step - loss: 0.8749 - accuracy: 0.6490 - val_loss: 0.7368 - val_accuracy: 0.7353
# Epoch 103/150
# 19/19 [==============================] - 7s 390ms/step - loss: 0.8748 - accuracy: 0.6490 - val_loss: 0.7367 - val_accuracy: 0.7353
# Epoch 104/150
# 19/19 [==============================] - 8s 404ms/step - loss: 0.8747 - accuracy: 0.6490 - val_loss: 0.7366 - val_accuracy: 0.7353
# Epoch 105/150
# 19/19 [==============================] - 7s 385ms/step - loss: 0.8745 - accuracy: 0.6490 - val_loss: 0.7364 - val_accuracy: 0.7353
# Epoch 106/150
# 19/19 [==============================] - 7s 380ms/step - loss: 0.8743 - accuracy: 0.6490 - val_loss: 0.7363 - val_accuracy: 0.7353
# Epoch 107/150
# 19/19 [==============================] - 8s 422ms/step - loss: 0.8742 - accuracy: 0.6490 - val_loss: 0.7362 - val_accuracy: 0.7353
# Epoch 108/150
# 19/19 [==============================] - 8s 425ms/step - loss: 0.8741 - accuracy: 0.6490 - val_loss: 0.7361 - val_accuracy: 0.7353
# Epoch 109/150
# 19/19 [==============================] - 7s 400ms/step - loss: 0.8740 - accuracy: 0.6490 - val_loss: 0.7360 - val_accuracy: 0.7353
# Epoch 110/150
# 19/19 [==============================] - 7s 393ms/step - loss: 0.8738 - accuracy: 0.6490 - val_loss: 0.7359 - val_accuracy: 0.7353
# Epoch 111/150
# 19/19 [==============================] - 7s 394ms/step - loss: 0.8737 - accuracy: 0.6490 - val_loss: 0.7358 - val_accuracy: 0.7353
# Epoch 112/150
# 19/19 [==============================] - 7s 395ms/step - loss: 0.8735 - accuracy: 0.6490 - val_loss: 0.7357 - val_accuracy: 0.7353
# Epoch 113/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8734 - accuracy: 0.6490 - val_loss: 0.7355 - val_accuracy: 0.7353
# Epoch 114/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8732 - accuracy: 0.6490 - val_loss: 0.7354 - val_accuracy: 0.7353
# Epoch 115/150
# 19/19 [==============================] - 7s 383ms/step - loss: 0.8731 - accuracy: 0.6490 - val_loss: 0.7353 - val_accuracy: 0.7353
# Epoch 116/150
# 19/19 [==============================] - 7s 382ms/step - loss: 0.8729 - accuracy: 0.6490 - val_loss: 0.7352 - val_accuracy: 0.7353
# Epoch 117/150
# 19/19 [==============================] - 7s 389ms/step - loss: 0.8729 - accuracy: 0.6490 - val_loss: 0.7351 - val_accuracy: 0.7353
# Epoch 118/150
# 19/19 [==============================] - 7s 392ms/step - loss: 0.8727 - accuracy: 0.6490 - val_loss: 0.7350 - val_accuracy: 0.7353
# Epoch 119/150
# 19/19 [==============================] - 9s 484ms/step - loss: 0.8725 - accuracy: 0.6490 - val_loss: 0.7349 - val_accuracy: 0.7353
# Epoch 120/150
# 19/19 [==============================] - 8s 432ms/step - loss: 0.8725 - accuracy: 0.6490 - val_loss: 0.7348 - val_accuracy: 0.7353
# Epoch 121/150
# 19/19 [==============================] - 7s 396ms/step - loss: 0.8723 - accuracy: 0.6490 - val_loss: 0.7347 - val_accuracy: 0.7353
# Epoch 122/150
# 19/19 [==============================] - 8s 406ms/step - loss: 0.8722 - accuracy: 0.6490 - val_loss: 0.7346 - val_accuracy: 0.7353
# Epoch 123/150
# 19/19 [==============================] - 7s 383ms/step - loss: 0.8720 - accuracy: 0.6490 - val_loss: 0.7345 - val_accuracy: 0.7353
# Epoch 124/150
# 19/19 [==============================] - 7s 387ms/step - loss: 0.8719 - accuracy: 0.6490 - val_loss: 0.7344 - val_accuracy: 0.7353
# Epoch 125/150
# 19/19 [==============================] - 8s 455ms/step - loss: 0.8717 - accuracy: 0.6490 - val_loss: 0.7343 - val_accuracy: 0.7353
# Epoch 126/150
# 19/19 [==============================] - 8s 429ms/step - loss: 0.8716 - accuracy: 0.6490 - val_loss: 0.7342 - val_accuracy: 0.7353
# Epoch 127/150
# 19/19 [==============================] - 8s 410ms/step - loss: 0.8715 - accuracy: 0.6490 - val_loss: 0.7341 - val_accuracy: 0.7353
# Epoch 128/150
# 19/19 [==============================] - 7s 403ms/step - loss: 0.8713 - accuracy: 0.6490 - val_loss: 0.7340 - val_accuracy: 0.7353
# Epoch 129/150
# 19/19 [==============================] - 8s 408ms/step - loss: 0.8712 - accuracy: 0.6490 - val_loss: 0.7339 - val_accuracy: 0.7353
# Epoch 130/150
# 19/19 [==============================] - 7s 383ms/step - loss: 0.8711 - accuracy: 0.6490 - val_loss: 0.7338 - val_accuracy: 0.7353
# Epoch 131/150
# 19/19 [==============================] - 7s 389ms/step - loss: 0.8710 - accuracy: 0.6490 - val_loss: 0.7337 - val_accuracy: 0.7353
# Epoch 132/150
# 19/19 [==============================] - 7s 385ms/step - loss: 0.8709 - accuracy: 0.6490 - val_loss: 0.7336 - val_accuracy: 0.7353
# Epoch 133/150
# 19/19 [==============================] - 8s 434ms/step - loss: 0.8707 - accuracy: 0.6490 - val_loss: 0.7335 - val_accuracy: 0.7353
# Epoch 134/150
# 19/19 [==============================] - 7s 378ms/step - loss: 0.8706 - accuracy: 0.6490 - val_loss: 0.7334 - val_accuracy: 0.7353
# Epoch 135/150
# 19/19 [==============================] - 7s 391ms/step - loss: 0.8704 - accuracy: 0.6490 - val_loss: 0.7333 - val_accuracy: 0.7353
# Epoch 136/150
# 19/19 [==============================] - 7s 393ms/step - loss: 0.8704 - accuracy: 0.6490 - val_loss: 0.7332 - val_accuracy: 0.7353
# Epoch 137/150
# 19/19 [==============================] - 8s 426ms/step - loss: 0.8703 - accuracy: 0.6490 - val_loss: 0.7332 - val_accuracy: 0.7353
# Epoch 138/150
# 19/19 [==============================] - 7s 379ms/step - loss: 0.8701 - accuracy: 0.6490 - val_loss: 0.7331 - val_accuracy: 0.7353
# Epoch 139/150
# 19/19 [==============================] - 7s 379ms/step - loss: 0.8700 - accuracy: 0.6490 - val_loss: 0.7330 - val_accuracy: 0.7353
# Epoch 140/150
# 19/19 [==============================] - 7s 401ms/step - loss: 0.8698 - accuracy: 0.6490 - val_loss: 0.7329 - val_accuracy: 0.7353
# Epoch 141/150
# 19/19 [==============================] - 8s 428ms/step - loss: 0.8697 - accuracy: 0.6490 - val_loss: 0.7328 - val_accuracy: 0.7353
# Epoch 142/150
# 19/19 [==============================] - 7s 386ms/step - loss: 0.8696 - accuracy: 0.6490 - val_loss: 0.7327 - val_accuracy: 0.7353
# Epoch 143/150
# 19/19 [==============================] - 7s 400ms/step - loss: 0.8695 - accuracy: 0.6490 - val_loss: 0.7326 - val_accuracy: 0.7353
# Epoch 144/150
# 19/19 [==============================] - 8s 451ms/step - loss: 0.8694 - accuracy: 0.6490 - val_loss: 0.7325 - val_accuracy: 0.7353
# Epoch 145/150
# ...
# Epoch 46/150
# 19/19 [==============================] - 14s 776ms/step - loss: 0.8641 - accuracy: 0.6490 - val_loss: 0.7439 - val_accuracy: 0.7353
# Epoch 47/150
# 19/19 [==============================] - 14s 750ms/step - loss: 0.8635 - accuracy: 0.6490 - val_loss: 0.7431 - val_accuracy: 0.7353
# Epoch 48/150
# 19/19 [==============================] - 16s 887ms/step - loss: 0.8630 - accuracy: 0.6490 - val_loss: 0.7423 - val_accuracy: 0.7353
# Epoch 49/150
# 19/19 [==============================] - 14s 777ms/step - loss: 0.8623 - accuracy: 0.6490 - val_loss: 0.7415 - val_accuracy: 0.7353
# Epoch 50/150
# 19/19 [==============================] - 14s 758ms/step - loss: 0.8619 - accuracy: 0.6490 - val_loss: 0.7408 - val_accuracy: 0.7353
# Epoch 51/150
# 19/19 [==============================] - 14s 754ms/step - loss: 0.8613 - accuracy: 0.6490 - val_loss: 0.7400 - val_accuracy: 0.7353
# Epoch 52/150
# 19/19 [==============================] - 15s 823ms/step - loss: 0.8609 - accuracy: 0.6490 - val_loss: 0.7394 - val_accuracy: 0.7353
# Epoch 53/150
# 19/19 [==============================] - 14s 770ms/step - loss: 0.8603 - accuracy: 0.6490 - val_loss: 0.7387 - val_accuracy: 0.7353
# Epoch 54/150
# 19/19 [==============================] - 14s 754ms/step - loss: 0.8598 - accuracy: 0.6490 - val_loss: 0.7380 - val_accuracy: 0.7353
# Epoch 55/150
# 19/19 [==============================] - 15s 787ms/step - loss: 0.8592 - accuracy: 0.6490 - val_loss: 0.7374 - val_accuracy: 0.7353
# Epoch 56/150
# 19/19 [==============================] - 15s 808ms/step - loss: 0.8588 - accuracy: 0.6490 - val_loss: 0.7367 - val_accuracy: 0.7353
# Epoch 57/150
# 19/19 [==============================] - 15s 776ms/step - loss: 0.8583 - accuracy: 0.6490 - val_loss: 0.7361 - val_accuracy: 0.7353
# Epoch 58/150
# 19/19 [==============================] - 14s 769ms/step - loss: 0.8578 - accuracy: 0.6490 - val_loss: 0.7355 - val_accuracy: 0.7353
# Epoch 59/150
# 19/19 [==============================] - 14s 779ms/step - loss: 0.8573 - accuracy: 0.6490 - val_loss: 0.7349 - val_accuracy: 0.7353
# Epoch 60/150
# 19/19 [==============================] - 14s 759ms/step - loss: 0.8568 - accuracy: 0.6490 - val_loss: 0.7343 - val_accuracy: 0.7353
# Epoch 61/150
# 19/19 [==============================] - 16s 833ms/step - loss: 0.8563 - accuracy: 0.6490 - val_loss: 0.7337 - val_accuracy: 0.7353
# Epoch 62/150
# 19/19 [==============================] - 15s 824ms/step - loss: 0.8558 - accuracy: 0.6490 - val_loss: 0.7331 - val_accuracy: 0.7353
# Epoch 63/150
# 19/19 [==============================] - 15s 785ms/step - loss: 0.8554 - accuracy: 0.6490 - val_loss: 0.7326 - val_accuracy: 0.7353
# Epoch 64/150
# 19/19 [==============================] - 14s 749ms/step - loss: 0.8549 - accuracy: 0.6490 - val_loss: 0.7320 - val_accuracy: 0.7353
# Epoch 65/150
# 19/19 [==============================] - 14s 766ms/step - loss: 0.8545 - accuracy: 0.6490 - val_loss: 0.7315 - val_accuracy: 0.7353
# Epoch 66/150
# 19/19 [==============================] - 14s 780ms/step - loss: 0.8541 - accuracy: 0.6490 - val_loss: 0.7309 - val_accuracy: 0.7353
# Epoch 67/150
# 19/19 [==============================] - 15s 788ms/step - loss: 0.8536 - accuracy: 0.6490 - val_loss: 0.7304 - val_accuracy: 0.7353
# Epoch 68/150
# 19/19 [==============================] - 14s 764ms/step - loss: 0.8532 - accuracy: 0.6490 - val_loss: 0.7298 - val_accuracy: 0.7353
# Epoch 69/150
# 19/19 [==============================] - 14s 762ms/step - loss: 0.8527 - accuracy: 0.6490 - val_loss: 0.7293 - val_accuracy: 0.7353
# Epoch 70/150
# 19/19 [==============================] - 14s 754ms/step - loss: 0.8523 - accuracy: 0.6490 - val_loss: 0.7288 - val_accuracy: 0.7353
# Epoch 71/150
# 19/19 [==============================] - 14s 757ms/step - loss: 0.8519 - accuracy: 0.6490 - val_loss: 0.7283 - val_accuracy: 0.7353
# Epoch 72/150
# 19/19 [==============================] - 14s 767ms/step - loss: 0.8514 - accuracy: 0.6490 - val_loss: 0.7278 - val_accuracy: 0.7353
# Epoch 73/150
# 19/19 [==============================] - 14s 764ms/step - loss: 0.8510 - accuracy: 0.6490 - val_loss: 0.7273 - val_accuracy: 0.7353
# Epoch 74/150
# 19/19 [==============================] - 14s 759ms/step - loss: 0.8506 - accuracy: 0.6490 - val_loss: 0.7268 - val_accuracy: 0.7353
# Epoch 75/150
# 19/19 [==============================] - 15s 790ms/step - loss: 0.8502 - accuracy: 0.6490 - val_loss: 0.7263 - val_accuracy: 0.7353
# Epoch 76/150
# 19/19 [==============================] - 15s 811ms/step - loss: 0.8497 - accuracy: 0.6490 - val_loss: 0.7258 - val_accuracy: 0.7353
# Epoch 77/150
# 19/19 [==============================] - 15s 819ms/step - loss: 0.8493 - accuracy: 0.6490 - val_loss: 0.7253 - val_accuracy: 0.7353
# Epoch 78/150
# 19/19 [==============================] - 14s 762ms/step - loss: 0.8490 - accuracy: 0.6490 - val_loss: 0.7249 - val_accuracy: 0.7353
# Epoch 79/150
# 19/19 [==============================] - 14s 771ms/step - loss: 0.8486 - accuracy: 0.6490 - val_loss: 0.7244 - val_accuracy: 0.7353
# Epoch 80/150
# 19/19 [==============================] - 15s 785ms/step - loss: 0.8481 - accuracy: 0.6490 - val_loss: 0.7239 - val_accuracy: 0.7353
# Epoch 81/150
# 19/19 [==============================] - 14s 760ms/step - loss: 0.8477 - accuracy: 0.6490 - val_loss: 0.7234 - val_accuracy: 0.7353
# Epoch 82/150
# 19/19 [==============================] - 14s 774ms/step - loss: 0.8474 - accuracy: 0.6490 - val_loss: 0.7230 - val_accuracy: 0.7353
# Epoch 83/150
# 19/19 [==============================] - 14s 759ms/step - loss: 0.8470 - accuracy: 0.6490 - val_loss: 0.7225 - val_accuracy: 0.7353
# Epoch 84/150
# 19/19 [==============================] - 14s 770ms/step - loss: 0.8466 - accuracy: 0.6490 - val_loss: 0.7221 - val_accuracy: 0.7353
# Epoch 85/150
# 19/19 [==============================] - 15s 807ms/step - loss: 0.8462 - accuracy: 0.6490 - val_loss: 0.7216 - val_accuracy: 0.7353
# Epoch 86/150
# 19/19 [==============================] - 14s 761ms/step - loss: 0.8459 - accuracy: 0.6490 - val_loss: 0.7212 - val_accuracy: 0.7353
# Epoch 87/150
# 19/19 [==============================] - 15s 785ms/step - loss: 0.8455 - accuracy: 0.6490 - val_loss: 0.7207 - val_accuracy: 0.7353
# Epoch 88/150
# 19/19 [==============================] - 14s 769ms/step - loss: 0.8451 - accuracy: 0.6490 - val_loss: 0.7203 - val_accuracy: 0.7353
# Epoch 89/150
# 19/19 [==============================] - 16s 885ms/step - loss: 0.8448 - accuracy: 0.6490 - val_loss: 0.7199 - val_accuracy: 0.7353
# Epoch 90/150
# 19/19 [==============================] - 14s 768ms/step - loss: 0.8444 - accuracy: 0.6490 - val_loss: 0.7194 - val_accuracy: 0.7353
# Epoch 91/150
# 19/19 [==============================] - 14s 773ms/step - loss: 0.8441 - accuracy: 0.6490 - val_loss: 0.7190 - val_accuracy: 0.7353
# Epoch 92/150
# 19/19 [==============================] - 14s 752ms/step - loss: 0.8437 - accuracy: 0.6490 - val_loss: 0.7186 - val_accuracy: 0.7353
# Epoch 93/150
# 19/19 [==============================] - 15s 784ms/step - loss: 0.8434 - accuracy: 0.6490 - val_loss: 0.7182 - val_accuracy: 0.7353
# Epoch 94/150
# 19/19 [==============================] - 14s 761ms/step - loss: 0.8430 - accuracy: 0.6490 - val_loss: 0.7178 - val_accuracy: 0.7353
# Epoch 95/150
# 19/19 [==============================] - 14s 762ms/step - loss: 0.8426 - accuracy: 0.6490 - val_loss: 0.7174 - val_accuracy: 0.7353
# Epoch 96/150
# 19/19 [==============================] - 14s 766ms/step - loss: 0.8423 - accuracy: 0.6490 - val_loss: 0.7169 - val_accuracy: 0.7353
# Epoch 97/150
# 19/19 [==============================] - 14s 758ms/step - loss: 0.8419 - accuracy: 0.6490 - val_loss: 0.7165 - val_accuracy: 0.7353
# Epoch 98/150
# 19/19 [==============================] - 14s 758ms/step - loss: 0.8416 - accuracy: 0.6490 - val_loss: 0.7161 - val_accuracy: 0.7353
# Epoch 99/150
# 19/19 [==============================] - 15s 786ms/step - loss: 0.8413 - accuracy: 0.6490 - val_loss: 0.7158 - val_accuracy: 0.7353
# Epoch 100/150
# 19/19 [==============================] - 14s 765ms/step - loss: 0.8409 - accuracy: 0.6490 - val_loss: 0.7154 - val_accuracy: 0.7353
# Epoch 101/150
# 19/19 [==============================] - 14s 759ms/step - loss: 0.8406 - accuracy: 0.6490 - val_loss: 0.7150 - val_accuracy: 0.7353
# Epoch 102/150
# 19/19 [==============================] - 14s 769ms/step - loss: 0.8403 - accuracy: 0.6490 - val_loss: 0.7146 - val_accuracy: 0.7353
# Epoch 103/150
# 19/19 [==============================] - 14s 757ms/step - loss: 0.8400 - accuracy: 0.6490 - val_loss: 0.7142 - val_accuracy: 0.7353
# Epoch 104/150
# 19/19 [==============================] - 14s 742ms/step - loss: 0.8397 - accuracy: 0.6490 - val_loss: 0.7138 - val_accuracy: 0.7353
# Epoch 105/150
# 19/19 [==============================] - 14s 749ms/step - loss: 0.8394 - accuracy: 0.6490 - val_loss: 0.7135 - val_accuracy: 0.7353
# Epoch 106/150
# 19/19 [==============================] - 14s 771ms/step - loss: 0.8390 - accuracy: 0.6490 - val_loss: 0.7131 - val_accuracy: 0.7353
# Epoch 107/150
# 19/19 [==============================] - 14s 758ms/step - loss: 0.8387 - accuracy: 0.6490 - val_loss: 0.7127 - val_accuracy: 0.7353
# Epoch 108/150
# 19/19 [==============================] - 15s 801ms/step - loss: 0.8384 - accuracy: 0.6490 - val_loss: 0.7123 - val_accuracy: 0.7353
# Epoch 109/150
# 19/19 [==============================] - 15s 800ms/step - loss: 0.8381 - accuracy: 0.6490 - val_loss: 0.7120 - val_accuracy: 0.7353
# Epoch 110/150
# 19/19 [==============================] - 14s 773ms/step - loss: 0.8378 - accuracy: 0.6490 - val_loss: 0.7116 - val_accuracy: 0.7353
# Epoch 111/150
# 19/19 [==============================] - 15s 830ms/step - loss: 0.8375 - accuracy: 0.6490 - val_loss: 0.7113 - val_accuracy: 0.7353
# Epoch 112/150
# 19/19 [==============================] - 14s 767ms/step - loss: 0.8371 - accuracy: 0.6490 - val_loss: 0.7109 - val_accuracy: 0.7353
# Epoch 113/150
# 19/19 [==============================] - 14s 759ms/step - loss: 0.8369 - accuracy: 0.6490 - val_loss: 0.7106 - val_accuracy: 0.7353
# Epoch 114/150
# 19/19 [==============================] - 14s 758ms/step - loss: 0.8365 - accuracy: 0.6490 - val_loss: 0.7102 - val_accuracy: 0.7353
# Epoch 115/150
# 19/19 [==============================] - 15s 821ms/step - loss: 0.8363 - accuracy: 0.6490 - val_loss: 0.7099 - val_accuracy: 0.7353
# Epoch 116/150
# 19/19 [==============================] - 15s 789ms/step - loss: 0.8360 - accuracy: 0.6490 - val_loss: 0.7095 - val_accuracy: 0.7353
# Epoch 117/150
# 19/19 [==============================] - 16s 880ms/step - loss: 0.8357 - accuracy: 0.6490 - val_loss: 0.7092 - val_accuracy: 0.7353
# Epoch 118/150
# 19/19 [==============================] - 14s 749ms/step - loss: 0.8354 - accuracy: 0.6490 - val_loss: 0.7089 - val_accuracy: 0.7353
# Epoch 119/150
# 19/19 [==============================] - 14s 748ms/step - loss: 0.8351 - accuracy: 0.6490 - val_loss: 0.7085 - val_accuracy: 0.7353
# Epoch 120/150
# 19/19 [==============================] - 14s 740ms/step - loss: 0.8348 - accuracy: 0.6490 - val_loss: 0.7082 - val_accuracy: 0.7353
# Epoch 121/150
# 19/19 [==============================] - 14s 751ms/step - loss: 0.8345 - accuracy: 0.6490 - val_loss: 0.7079 - val_accuracy: 0.7353
# Epoch 122/150
# 19/19 [==============================] - 14s 750ms/step - loss: 0.8343 - accuracy: 0.6490 - val_loss: 0.7075 - val_accuracy: 0.7353
# Epoch 123/150
# 19/19 [==============================] - 14s 746ms/step - loss: 0.8339 - accuracy: 0.6490 - val_loss: 0.7072 - val_accuracy: 0.7353
# Epoch 124/150
# 19/19 [==============================] - 14s 746ms/step - loss: 0.8337 - accuracy: 0.6490 - val_loss: 0.7069 - val_accuracy: 0.7353
# Epoch 125/150
# 19/19 [==============================] - 14s 748ms/step - loss: 0.8334 - accuracy: 0.6490 - val_loss: 0.7066 - val_accuracy: 0.7353
# Epoch 126/150
# 19/19 [==============================] - 15s 827ms/step - loss: 0.8332 - accuracy: 0.6490 - val_loss: 0.7063 - val_accuracy: 0.7353
# Epoch 127/150
# 19/19 [==============================] - 12s 666ms/step - loss: 0.8329 - accuracy: 0.6490 - val_loss: 0.7059 - val_accuracy: 0.7353
# Epoch 128/150
# 19/19 [==============================] - 12s 631ms/step - loss: 0.8326 - accuracy: 0.6490 - val_loss: 0.7056 - val_accuracy: 0.7353
# Epoch 129/150
# 19/19 [==============================] - 12s 631ms/step - loss: 0.8323 - accuracy: 0.6490 - val_loss: 0.7053 - val_accuracy: 0.7353
# Epoch 130/150
# 19/19 [==============================] - 11s 619ms/step - loss: 0.8320 - accuracy: 0.6490 - val_loss: 0.7050 - val_accuracy: 0.7353
# Epoch 131/150
# 19/19 [==============================] - 13s 679ms/step - loss: 0.8318 - accuracy: 0.6490 - val_loss: 0.7047 - val_accuracy: 0.7353
# Epoch 132/150
# 19/19 [==============================] - 13s 669ms/step - loss: 0.8315 - accuracy: 0.6490 - val_loss: 0.7044 - val_accuracy: 0.7353
# Epoch 133/150
# 19/19 [==============================] - 12s 651ms/step - loss: 0.8312 - accuracy: 0.6490 - val_loss: 0.7041 - val_accuracy: 0.7353
# Epoch 134/150
# 19/19 [==============================] - 12s 639ms/step - loss: 0.8310 - accuracy: 0.6490 - val_loss: 0.7038 - val_accuracy: 0.7353
# Epoch 135/150
# 19/19 [==============================] - 12s 635ms/step - loss: 0.8308 - accuracy: 0.6490 - val_loss: 0.7035 - val_accuracy: 0.7353
# Epoch 136/150
# 19/19 [==============================] - 12s 664ms/step - loss: 0.8305 - accuracy: 0.6490 - val_loss: 0.7033 - val_accuracy: 0.7353
# Epoch 137/150
# 19/19 [==============================] - 12s 629ms/step - loss: 0.8302 - accuracy: 0.6490 - val_loss: 0.7030 - val_accuracy: 0.7353
# Epoch 138/150
# 19/19 [==============================] - 11s 621ms/step - loss: 0.8300 - accuracy: 0.6490 - val_loss: 0.7027 - val_accuracy: 0.7353
# Epoch 139/150
# 19/19 [==============================] - 12s 636ms/step - loss: 0.8297 - accuracy: 0.6490 - val_loss: 0.7024 - val_accuracy: 0.7353
# Epoch 140/150
# 19/19 [==============================] - 12s 630ms/step - loss: 0.8294 - accuracy: 0.6490 - val_loss: 0.7021 - val_accuracy: 0.7353
# Epoch 141/150
# 19/19 [==============================] - 11s 614ms/step - loss: 0.8292 - accuracy: 0.6490 - val_loss: 0.7018 - val_accuracy: 0.7353
# Epoch 142/150
# 19/19 [==============================] - 12s 633ms/step - loss: 0.8289 - accuracy: 0.6490 - val_loss: 0.7016 - val_accuracy: 0.7353
# Epoch 143/150
# 19/19 [==============================] - 12s 624ms/step - loss: 0.8287 - accuracy: 0.6490 - val_loss: 0.7013 - val_accuracy: 0.7353
# Epoch 144/150
# 19/19 [==============================] - 12s 623ms/step - loss: 0.8284 - accuracy: 0.6490 - val_loss: 0.7010 - val_accuracy: 0.7353
# Epoch 145/150
# 19/19 [==============================] - 12s 622ms/step - loss: 0.8282 - accuracy: 0.6490 - val_loss: 0.7007 - val_accuracy: 0.7353
# Epoch 146/150
# 19/19 [==============================] - 12s 627ms/step - loss: 0.8279 - accuracy: 0.6490 - val_loss: 0.7005 - val_accuracy: 0.7353
# Epoch 147/150
# 19/19 [==============================] - 11s 622ms/step - loss: 0.8277 - accuracy: 0.6490 - val_loss: 0.7002 - val_accuracy: 0.7353
# Epoch 148/150
# 19/19 [==============================] - 11s 622ms/step - loss: 0.8274 - accuracy: 0.6490 - val_loss: 0.6999 - val_accuracy: 0.7353
# Epoch 149/150
# 19/19 [==============================] - 11s 615ms/step - loss: 0.8272 - accuracy: 0.6490 - val_loss: 0.6997 - val_accuracy: 0.7353
# Epoch 150/150
# 19/19 [==============================] - 11s 619ms/step - loss: 0.8270 - accuracy: 0.6490 - val_loss: 0.6994 - val_accuracy: 0.7353
# 3/3 [==============================] - 1s 165ms/step
# d:\Documents\Workspaces\Python\image-classification\.venv\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Documents\Workspaces\Python\image-classification\.venv\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results
# Out:
#    n_filters optimizer  learning_rate  epochs   name  accuracy  precision  \
# 0         32      Adam         0.0010     150  U-Net  0.552941   0.537152
# 1         32      Adam         0.0001     150  U-Net  0.576471   0.522689
# 2         32       SGD         0.0010     150  U-Net  0.600000   0.530560
# 3         32       SGD         0.0001     150  U-Net  0.564706   0.318893
# 4         64      Adam         0.0010     150  U-Net  0.600000   0.657919
# 5         64      Adam         0.0001     150  U-Net  0.482353   0.452393
# 6         64       SGD         0.0010     150  U-Net  0.611765   0.614000
# 7         64       SGD         0.0001     150  U-Net  0.564706   0.318893
#
#      recall  f1_score
# 0  0.552941  0.532571
# 1  0.576471  0.432917
# 2  0.600000  0.477014
# 3  0.564706  0.407607
# 4  0.600000  0.497809
# 5  0.482353  0.461941
# 6  0.611765  0.533823
# 7  0.564706  0.407607

# %% [markdown]
# ## Implantação do Modelo e Geração de Valor
#
# A partir dos dados obtidos é possível visualizar qual a melhor combinação de hiperparâmetros para o modelo de rede neural usado. Por exemplo, podemos usar o modelo que teve maior acurácia ou um que se ajustou aos objetivos do trabalho (acurácia maior que 70%)
#
# ### Implantação
# Após escolher o modelo, sua implantação pode ser feita a partir de uma API web onde o usuário enviar uma fotografia de planta e recebe como resultado a espécie planta sugerida pelo modelo. Essa API pode ser facilmente integrada a outros sistemas, por exemplo o sistema de cadastramento de mudas de plantas, ou sistemas que precisam catalogar as flores adquiridas de maneira rápida e eficiente.
#
# ### Calculo de Ganhos
# Os ganhos positivos podem ser calculadas a medida que os usuários usam o modelo para facilitar
# * O tempo de identificação das amostras de plantas
# * Os gastos com alimentação e transporte de um funcionário especializado para o local
#
# ### Monitoramento
# O monitoramento pode ser feito de maneira constante junto com os dados que estão sendo enviados pela API do sistema. Caso a acurácia atual esteja menor que o padrão desejado pode ser necessário refazer o treinamento com dados mais atualizados.
